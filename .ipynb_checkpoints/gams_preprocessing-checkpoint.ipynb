# %% [markdown]
# # Data pre-processing on the GAMS dataset
#
# In this notebook, the data from the gams dataset are loaded and pre-processed so that they can be used for training machine learning models. The processed data re written in a csv file for direct access

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import seaborn as sns
import warnings


warnings.filterwarnings('ignore')
# %matplotlib inline

# setting plot styles
plt.style.use('seaborn-whitegrid')
plt.rcParams["figure.figsize"] = (20,10)
plt.rcParams["font.size"] = 22

# %% [markdown]
# ## Data importing and basic pre-processing

# %%
gams_url = 'https://raw.githubusercontent.com/twairball/gams-dataset/master/gams_indoor.csv'
gams_df = pd.read_csv(gams_url, index_col='ts')
gams_df.head()
# Out:
#                        co2  humidity  pm10  pm25  temperature    voc
# ts
# 2016-11-21 00:47:03  708.0     72.09  10.2   9.0        20.83  0.062
# 2016-11-21 00:48:03  694.0     70.95  10.9  10.1        21.01  0.062
# 2016-11-21 00:49:03  693.0     69.12  10.2   9.9        21.20  0.062
# 2016-11-21 00:50:03  692.0     68.83   9.6   9.6        21.37  0.062
# 2016-11-21 00:51:03  690.0     68.60   9.4   8.4        21.49  0.062

# %%
gams_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 135099 entries, 2016-11-21 00:47:03 to 2017-03-28 09:30:03
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   co2          135099 non-null  float64
#  1   humidity     135099 non-null  float64
#  2   pm10         135099 non-null  float64
#  3   pm25         135099 non-null  float64
#  4   temperature  135099 non-null  float64
#  5   voc          135099 non-null  float64
# dtypes: float64(6)
# memory usage: 7.2+ MB

# %%
gams_df.describe()
# Out:
#                  co2       humidity           pm10           pm25  \
# count  135099.000000  135099.000000  135099.000000  135099.000000
# mean      688.833011      37.879496      17.553535      15.801651
# std       385.845573       5.284216      12.603744      11.709474
# min       369.000000      21.970000       0.500000       0.500000
# 25%       429.000000      34.490000       8.400000       7.300000
# 50%       483.000000      37.640000      14.000000      12.300000
# 75%       852.000000      41.290000      23.400000      21.000000
# max      2626.000000      72.090000     142.600000      85.200000
#
#          temperature            voc
# count  135099.000000  135099.000000
# mean       22.939613       0.121050
# std         2.051068       0.089947
# min        17.710000       0.062000
# 25%        21.410000       0.064000
# 50%        22.860000       0.076000
# 75%        24.650000       0.149000
# max        27.960000       2.000000

# %% [markdown]
# Convert to hourly observations

# %%
gams_df.index = pd.to_datetime(gams_df.index) # convert index to datetime object
gams_df.drop('pm10', axis=1, inplace=True) # delete PM10
# gams_hourly_df = gams_df.resample('60min').mean() # resample to hourly observations
gams_5min_df = gams_df.resample('5min').mean() # resample to 5min observations
print("Data points after resampling: {}".format(gams_5min_df.shape[0]))
print(gams_5min_df.head())
# Out:
# Data points after resampling: 36682
#                             co2  humidity      pm25  temperature    voc
# ts
# 2016-11-21 00:45:00  698.333333    70.720  9.666667    21.013333  0.062
# 2016-11-21 00:50:00  690.600000    68.328  7.800000    21.642000  0.062
# 2016-11-21 00:55:00  694.400000    66.954  6.940000    22.252000  0.062
# 2016-11-21 01:00:00  697.000000    65.368  6.240000    22.772000  0.062
# 2016-11-21 01:05:00  705.400000    64.066  5.380000    23.130000  0.062

# %% [markdown]
# Normalizing the data in the range [0,1]

# %%
# timestamps = gams_hourly_df.index
# scaler = MinMaxScaler()
# gams_hourly_normed = scaler.fit_transform(gams_hourly_df) # result is numpy array
# gams_hourly_df = pd.DataFrame(gams_hourly_normed, columns=gams_df.columns, index=timestamps) # re-write bac to the original dataframe
# gams_hourly_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-9b12b971515f> in <module>
# ----> 1 timestamps = gams_hourly_df.index
#       2 # scaler = MinMaxScaler()
#       3 # gams_hourly_normed = scaler.fit_transform(gams_hourly_df) # result is numpy array
#       4 # gams_hourly_df = pd.DataFrame(gams_hourly_normed, columns=gams_df.columns, index=timestamps) # re-write bac to the original dataframe
#       5 # gams_hourly_df.head()
#
# NameError: name 'gams_hourly_df' is not defined

# %%
# gams_hourly_df.info()

# %% [markdown]
# Visualizing missing values

# %%
nulls_df = gams_5min_df.isnull()
print("Rows with at least one nan: ")
# print(np.where(np.asanyarray(np.isnan(gams_hourly_df)))[0])
sns.heatmap(nulls_df, cbar=False); # distribution of nans
# Out:
# Rows with at least one nan:

# %% [markdown]
# Filling missing values using k-nn imputation

# %%
# gams_hourly_df.fillna(gams_hourly_df.mean(), inplace=True)

def knn_imputation(df):
    """ Imputes missing values based on the k-nn method

        INPUT: df = a dataframe

        OUTPUT: df_filled = a numpy array withn nan's filled
    """

    from sklearn.impute import KNNImputer
    k = int(round(np.sqrt(len(df))))
    # print(k)
    imputer = KNNImputer(n_neighbors=k)
    df_filled = imputer.fit_transform(df)

    return df_filled


gams_5min_filled = knn_imputation(gams_5min_df) # returns numpy array
gams_5min_df = pd.DataFrame(gams_5min_filled, columns=gams_df.columns, index=gams_5min_df.index) # write back to the original dataframe
gams_5min_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 36682 entries, 2016-11-21 00:45:00 to 2017-03-28 09:30:00
# Freq: 5T
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   co2          36682 non-null  float64
#  1   humidity     36682 non-null  float64
#  2   pm25         36682 non-null  float64
#  3   temperature  36682 non-null  float64
#  4   voc          36682 non-null  float64
# dtypes: float64(5)
# memory usage: 1.7 MB

# %% [markdown]
# **Plot the processed data and show some range information**

# %%
gams_5min_df.plot(subplots=True);

# %%
gams_5min_df.describe()
# Out:
#                 co2      humidity          pm25   temperature           voc
# count  36682.000000  36682.000000  36682.000000  36682.000000  36682.000000
# mean     710.576019     38.378785     15.880187     22.993829      0.116947
# std      395.059999      5.325371     11.820227      2.029423      0.083636
# min      370.333333     22.054000      0.550000     18.020000      0.062000
# 25%      433.500000     34.838500      7.320000     21.490000      0.063600
# 50%      506.000000     38.378785     12.740000     22.993829      0.078000
# 75%      856.000000     41.725750     20.550000     24.666000      0.136000
# max     2608.000000     70.720000     85.200000     27.955000      0.907750

# %% [markdown]
# From the range information we conclude that it might not be meaningful to train a temperature forecasting model, since the data come from controlled temperature places. The model will always predict temperatures within this controlled range.

# %% [markdown]
# **Write processed data to csv**

# %%
gams_5min_df.head()

# %%
gams_5min_df.to_csv('gams_processed_5min.csv', index=True)

# %% [markdown]
# **Example of reading the csv file**

# %%
gams_pr_df = pd.read_csv('gams_processed_5min.csv')
gams_pr_df.head()
